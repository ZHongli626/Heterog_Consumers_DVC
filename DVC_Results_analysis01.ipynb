# %% [markdown]
# After simulations, we get the results. Now we do an analysis of the results.

# %%
# position = r"C:\Users\think\sciebo\Digitalization_SC\Data Value Chain\Policy Analysis\New_Results_SPE"
# position0 = "C:/Users/zwang3/Downloads"
# position = r'C:\Users\zwang3\sciebo\Digitalization_SC\Data Value Chain\Policy Analysis\New_Results_SPE'
position = r"C:\Users\think\Downloads\New_data_DVC230731"

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import seaborn as sns

# %% [markdown]
# Symmetric settings: given certain data restriction levels, check the equilibrium prices under the same investment levels. The following shows the datasets: dset01 ($c_{res,a}=c_{res,b}=0$), dset02 ($c_{res,a}=c_{res,b}=5$), dset03 ($c_{res,a}=c_{res,b}=15$), dset04 ($c_{res,a}=c_{res,b}=20$).

# %%
dset01 = pd.read_csv(position0 + "/df_equil_new03_cres_sym_at_0.csv")
dset02 = pd.read_csv(position0 + "/df_equil_new01_cres_sym_at_5.csv")
dset03 = pd.read_csv(position0 + "/df_equil_new02_cres_sym_at_15.csv") # need to check
dset04 = pd.read_csv(position0 + "/df_equil_new04_cres_sym_at_20.csv") # need to check

# %% [markdown]
# Explanation of other datasets:

# %% [markdown]
# The columns of the datasets include $c_{0,b}$ (which is equal to $c_{0,a}$), $p_{b}$ (the best response price of Owner $b$), $\Pi_b$ (the profit of $b$) and the aggregate welfare.

# %%
dset01
# Out:
#     c_0_b  p_b  profit_b   agg_welfare
# 0     0.0  1.0    5018.0  1.956552e+06
# 1    10.0  1.0    4998.0  1.956512e+06
# 2    20.0  1.0    4978.0  1.956472e+06
# 3    30.0  1.0    4958.0  1.956432e+06
# 4    40.0  1.0    4938.0  1.956392e+06
# 5    50.0  1.0    4918.0  1.956352e+06
# 6    60.0  1.0    4898.0  1.956312e+06
# 7    70.0  1.0    4878.0  1.956272e+06
# 8    80.0  1.0    4858.0  1.956232e+06
# 9    90.0  1.0    4838.0  1.956192e+06
# 10  100.0  1.0    4818.0  1.956152e+06

# %%
plt.plot(dset01["c_0_b"], dset01["profit_b"], "blue")
plt.plot
plt.show()

# %% [markdown]
# Observations: When all Owners raise their investments to a same level, the best response prices do not change, the profit would decrease

# %%
dset01a = dset01.copy() # symmetric case: ($c_{res,a}=c_{res,b}=0$)
dset01a.loc[:, 'c_0_a'] = dset01a.loc[:, 'c_0_b']
dset01a
# Out:
#     c_0_b  p_b  profit_b   agg_welfare  c_0_a
# 0     0.0  1.0    5018.0  1.956552e+06    0.0
# 1    10.0  1.0    4998.0  1.956512e+06   10.0
# 2    20.0  1.0    4978.0  1.956472e+06   20.0
# 3    30.0  1.0    4958.0  1.956432e+06   30.0
# 4    40.0  1.0    4938.0  1.956392e+06   40.0
# 5    50.0  1.0    4918.0  1.956352e+06   50.0
# 6    60.0  1.0    4898.0  1.956312e+06   60.0
# 7    70.0  1.0    4878.0  1.956272e+06   70.0
# 8    80.0  1.0    4858.0  1.956232e+06   80.0
# 9    90.0  1.0    4838.0  1.956192e+06   90.0
# 10  100.0  1.0    4818.0  1.956152e+06  100.0

# %% [markdown]
# Heatmaps

# %%
heatmap01 = dset01a.pivot("c_0_b", "c_0_a", "profit_b")
sns.set(rc={'figure.figsize':(11.7,8.27),'figure.dpi': 100})
sns.heatmap(heatmap01, cmap="YlGnBu", linewidths=.5, annot=True, annot_kws={'size':10},fmt='.1f'
           )
plt.show()

# %%
heatmap01 = dset01a.pivot("c_0_b", "c_0_a", "p_b")
sns.set(rc={'figure.figsize':(11.7,8.27),'figure.dpi': 100})
sns.heatmap(heatmap01, cmap="YlGnBu", linewidths=.5, annot=True, annot_kws={'size':10},fmt='.1f')
plt.show()

# %%
dset02a = dset02.copy() # # symmetric case: ($c_{res,a}=c_{res,b}=5$)
dset02a.loc[:, 'c_0_a'] = dset02a.loc[:, 'c_0_b']
heatmap02 = dset02a.pivot("c_0_b", "c_0_a", "profit_b")
sns.set(rc={'figure.figsize':(11.7,8.27),'figure.dpi': 100})
sns.heatmap(heatmap02, cmap="YlGnBu", linewidths=.5, annot=True, annot_kws={'size':10},fmt='.1f')
plt.show()

# %%
heatmap02 = dset02a.pivot("c_0_b", "c_0_a", "p_b")
sns.set(rc={'figure.figsize':(11.7,8.27),'figure.dpi': 100})
sns.heatmap(heatmap02, cmap="YlGnBu", linewidths=.5, annot=True, annot_kws={'size':10},fmt='.1f')
plt.show()

# %%
dset03a = dset03.copy() # # symmetric case: ($c_{res,a}=c_{res,b}=10$)
dset03a.loc[:, 'c_0_a'] = dset03a.loc[:, 'c_0_b']
heatmap03 = dset03a.pivot("c_0_b", "c_0_a", "profit_b")
sns.set(rc={'figure.figsize':(11.7,8.27),'figure.dpi': 100})
sns.heatmap(heatmap03, cmap="YlGnBu", linewidths=.5, annot=True, annot_kws={'size':10},fmt='.1f')
plt.show()

# %%
heatmap03 = dset03a.pivot("c_0_b", "c_0_a", "p_b")
sns.set(rc={'figure.figsize':(11.7,8.27),'figure.dpi': 100})
sns.heatmap(heatmap03, cmap="YlGnBu", linewidths=.5, annot=True, annot_kws={'size':10},fmt='.1f')
plt.show()

# %%
dset04a = dset04.copy() # # symmetric case: ($c_{res,a}=c_{res,b}=15$)
dset04a.loc[:, 'c_0_a'] = dset04a.loc[:, 'c_0_b']
heatmap04 = dset04a.pivot("c_0_b", "c_0_a", "profit_b")
sns.set(rc={'figure.figsize':(11.7,8.27),'figure.dpi': 100})
sns.heatmap(heatmap04, cmap="YlGnBu", linewidths=.5, annot=True, annot_kws={'size':10},fmt='.1f')
plt.show()

# %%
heatmap04 = dset04a.pivot("c_0_b", "c_0_a", "p_b")
sns.set(rc={'figure.figsize':(11.7,8.27),'figure.dpi': 100})
sns.heatmap(heatmap04, cmap="YlGnBu", linewidths=.5, annot=True, annot_kws={'size':10},fmt='.1f')
plt.show()

# %% [markdown]
# Further results

# %% [markdown]
# Further experiments: Adjustments of the settings. Datasets: dset05 ($c_{res,a}=c_{res,b}=0$, $c_{0,a} + 1 = c_{0,b}$), dset06 ($c_{res,a}=c_{res,b}=0$, $c_{0,a} + 5 = c_{0,b}$), dset07 ($c_{res,a}=c_{res,b}=0$, $c_{0,a} + 10 = c_{0,b}$), dset08 ($c_{res,a}=c_{res,b}=0$, $c_{0,a} + 20 = c_{0,b}$).

# %%
dset05 = pd.read_csv(position0 + "/df_equil_new05_cres_asym_at_0.csv")
dset06 = pd.read_csv(position0 + "/df_equil_new06_cres_asym_at_0.csv")
dset07 = pd.read_csv(position0 + "/df_equil_new07_cres_asym_at_0.csv")
dset08 = pd.read_csv(position0 + "/df_equil_new08_cres_asym_at_0.csv")

# %%
dset05a = dset05.copy()
dset05a.loc[:,'c_0_a'] = dset05a.loc[:,'c_0_b'] - 1

# %%
dset06a = dset06.copy()
dset06a.loc[:,'c_0_a'] = dset06a.loc[:,'c_0_b'] - 5
dset07a = dset07.copy()
dset07a.loc[:,'c_0_a'] = dset07a.loc[:,'c_0_b'] - 10
dset08a = dset08.copy()
dset08a.loc[:,'c_0_a'] = dset08a.loc[:,'c_0_b'] - 20

# %%
# Aggregate heatmap under ($c_{res,a}=c_{res,b}=0$)
dset_0_0 = pd.concat([dset01a, dset05a, dset06a, dset07a, dset08a])

# %%
heatmap0_0 = dset_0_0.pivot("c_0_b", "c_0_a", "profit_b")
sns.set(rc={'figure.figsize':(11.7,8.27),'figure.dpi': 100})
sns.heatmap(heatmap0_0, cmap="YlGnBu", linewidths=.5, annot=True, annot_kws={'size':10},fmt='.1f')
plt.show()

# %%
heatmap0_0 = dset_0_0.pivot("c_0_b", "c_0_a", "p_b")
sns.set(rc={'figure.figsize':(11.7,8.27),'figure.dpi': 100})
sns.heatmap(heatmap0_0, cmap="YlGnBu", linewidths=.5, annot=True, annot_kws={'size':10},fmt='.1f')
plt.show()

# %% [markdown]
# Adjustments of the settings. Datasets: dset09 ($c_{res,a}=0, c_{res,b}=5$, $c_{0,a}=c_{0,b}$), dset10 ($c_{res,a}=0,c_{res,b}=10$, $c_{0,a} = c_{0,b}$), dset11 ($c_{res,a}=0,c_{res,b}=15$, $c_{0,a} = c_{0,b}$)

# %%
dset09 = pd.read_csv(position0 + "/df_equil_new09_cres_sym_at_0_5.csv")
dset10 = pd.read_csv(position0 + "/df_equil_new10_cres_sym_at_0_10.csv")
dset11 = pd.read_csv(position0 + "/df_equil_new11_cres_sym_at_0_15.csv")

# %%
# Robustness check
dset11_1 = pd.read_csv(position + "/df_equil_new11_1_cres_sym_at_0_15.csv")
# dset11 == dset11_1 # True

# %%
dset09a = dset09.copy()
dset09a.loc[:,'c_0_a'] = dset09a.loc[:,'c_0_b']
dset10a = dset10.copy()
dset10a.loc[:,'c_0_a'] = dset10a.loc[:,'c_0_b']
dset11a = dset11.copy()
dset11a.loc[:,'c_0_a'] = dset11a.loc[:,'c_0_b']

# %%
# dset09a

# %%
heatmap09 = dset09a.pivot("c_0_b", "c_0_a", "profit_b")
sns.set(rc={'figure.figsize':(11.7,8.27),'figure.dpi': 100})
sns.heatmap(heatmap09, cmap="YlGnBu", linewidths=.5, annot=True, annot_kws={'size':10},fmt='.1f')
plt.show()

# %%
heatmap09 = dset09a.pivot("c_0_b", "c_0_a", "p_b")
sns.set(rc={'figure.figsize':(11.7,8.27),'figure.dpi': 100})
sns.heatmap(heatmap09, cmap="YlGnBu", linewidths=.5, annot=True, annot_kws={'size':10},fmt='.1f')
plt.show()

# %%
heatmap10 = dset10a.pivot("c_0_b", "c_0_a", "profit_b")
sns.set(rc={'figure.figsize':(11.7,8.27),'figure.dpi': 100})
sns.heatmap(heatmap10, cmap="YlGnBu", linewidths=.5, annot=True, annot_kws={'size':10},fmt='.1f')
plt.show()

# %%
heatmap10 = dset10a.pivot("c_0_b", "c_0_a", "p_b")
sns.set(rc={'figure.figsize':(11.7,8.27),'figure.dpi': 100})
sns.heatmap(heatmap10, cmap="YlGnBu", linewidths=.5, annot=True, annot_kws={'size':10},fmt='.1f')
plt.show()

# %%
heatmap11 = dset11a.pivot("c_0_b", "c_0_a", "profit_b")
sns.set(rc={'figure.figsize':(11.7,8.27),'figure.dpi': 100})
sns.heatmap(heatmap11, cmap="YlGnBu", linewidths=.5, annot=True, annot_kws={'size':10},fmt='.1f')
plt.show()

# %%
heatmap11 = dset11a.pivot("c_0_b", "c_0_a", "p_b")
sns.set(rc={'figure.figsize':(11.7,8.27),'figure.dpi': 100})
sns.heatmap(heatmap11, cmap="YlGnBu", linewidths=.5, annot=True, annot_kws={'size':10},fmt='.1f')
plt.show()

# %% [markdown]
# Adjustments of the settings. Datasets: dset12 ($c_{res,a}=0, c_{res,b}=5$, $c_{0,a} + 5 = c_{0,b}$), dset13 ($c_{res,a}=0, c_{res,b}=5$, $c_{0,a} + 10 = c_{0,b}$), dset14 ($c_{res,a}=0,c_{res,b}=5$, $c_{0,a} + 15 = c_{0,b}$), dset15 ($c_{res,a}=0,c_{res,b}=5$, $c_{0,a} + 20 = c_{0,b}$), dset16 ($c_{res,a}=0,c_{res,b}=5$, $c_{0,a} - 5 = c_{0,b}$)

# %%
dset12 = pd.read_csv(position + "/df_equil_new12_cres_asym_at_0_5.csv")
dset13 = pd.read_csv(position + "/df_equil_new13_cres_asym_at_0_5.csv")
dset14 = pd.read_csv(position + "/df_equil_new14_cres_asym_at_0_5.csv")
dset15 = pd.read_csv(position + "/df_equil_new15_cres_asym_at_0_5.csv")
dset16 = pd.read_csv(position + "/df_equil_new16_cres_asym_at_0_5.csv")

# %%
dset12a = dset12.copy()
dset12a.loc[:,'c_0_a'] = dset12a.loc[:,'c_0_b'] - 5
dset13a = dset13.copy()
dset13a.loc[:,'c_0_a'] = dset13a.loc[:,'c_0_b'] - 10
dset14a = dset14.copy()
dset14a.loc[:,'c_0_a'] = dset14a.loc[:,'c_0_b'] - 15
dset15a = dset15.copy()
dset15a.loc[:,'c_0_a'] = dset15a.loc[:,'c_0_b'] - 20

# %%
dset16a = dset16.copy()
dset16a.loc[:,'c_0_a'] = dset16a.loc[:,'c_0_b'] + 5

# %%
dset_0_5
# Out:
#     c_0_b  p_b  profit_b   agg_welfare
# 0     0.0  7.0    9914.0  1.875691e+06
# 1    10.0  7.0    9894.0  1.875651e+06
# 2    20.0  7.0    9874.0  1.875611e+06
# 3    30.0  7.0    9854.0  1.875571e+06
# 4    40.0  7.0    9834.0  1.875531e+06
# ..    ...  ...       ...           ...
# 6    60.0  7.0    9794.0  1.875441e+06
# 7    70.0  7.0    9774.0  1.875401e+06
# 8    80.0  7.0    9754.0  1.875361e+06
# 9    90.0  7.0    9734.0  1.875321e+06
# 10  100.0  7.0    9714.0  1.875281e+06
#
# [66 rows x 4 columns]

# %%
# Aggregate heatmap under ($c_{res,a}=0,c_{res,b}=5$)
dset_0_5 = pd.concat([dset09a, dset12a, dset13a, dset14a, dset15a, dset16a])
heatmap0_5 = dset_0_5.pivot("c_0_b", "c_0_a", "profit_b")
sns.set(rc={'figure.figsize':(18.7,10.27),'figure.dpi': 100})
sns.heatmap(heatmap0_5, cmap="YlGnBu", linewidths=.5, annot=True, annot_kws={'size':10},fmt='.1f')
plt.show()

# %%
heatmap0_5 = dset_0_5.pivot("c_0_b", "c_0_a", "p_b")
sns.set(rc={'figure.figsize':(18.7,10.27),'figure.dpi': 100})
sns.heatmap(heatmap0_5, cmap="YlGnBu", linewidths=.5, annot=True, annot_kws={'size':10},fmt='.1f')
plt.show()

# %%
dset_new1 = pd.read_csv(position0 + "/df_equil_new002_added_res_0_0.csv")

# %%
dset_new1.to_excel(position0 + "/df_equil_new002_add_res_0_0.xlsx", index = False)

# %%
heatmap0_6 = dset_new1.pivot("c_0_b", "c_0_a", "price_s_b")
sns.set(rc={'figure.figsize':(18.7,10.27),'figure.dpi': 100})
ax = sns.heatmap(heatmap0_6, cmap="YlGnBu", linewidths=.5, annot=True, annot_kws={'size':10},fmt='.1f')
ax.invert_yaxis()
plt.show()

# %%
heatmap0_6 = dset_new1.pivot("c_0_b", "c_0_a", "price_s_a")
sns.set(rc={'figure.figsize':(18.7,10.27),'figure.dpi': 100})
ax = sns.heatmap(heatmap0_6, cmap="YlGnBu", linewidths=.5, annot=True, annot_kws={'size':10},fmt='.1f')
ax.invert_yaxis()
plt.show()

# %%
heatmap0_6 = dset_new1.pivot("c_0_b", "c_0_a", "pr2")
sns.set(rc={'figure.figsize':(18.7,10.27),'figure.dpi': 100})
ax = sns.heatmap(heatmap0_6, cmap="YlGnBu", linewidths=.5, annot=True, annot_kws={'size':10},fmt='.1f')
ax.invert_yaxis()
plt.show()

# %%
heatmap0_6 = dset_new1.pivot("c_0_b", "c_0_a", "agg_welfare")
sns.set(rc={'figure.figsize':(18.7,10.27),'figure.dpi': 100})
ax = sns.heatmap(heatmap0_6, cmap="YlGnBu", linewidths=.5, annot=True, 
                 annot_kws={'size':10},fmt='.1f')
ax.invert_yaxis()
plt.show()

# %%
heatmap0_6 = dset_new1.pivot("c_0_b", "c_0_a", "total_pr")
sns.set(rc={'figure.figsize':(18.7,10.27),'figure.dpi': 100})
ax = sns.heatmap(heatmap0_6, cmap="YlGnBu", linewidths=.5, annot=True, 
                 annot_kws={'size':10},fmt='.1f')
ax.invert_yaxis()
plt.show()

# %%
dset_new2 = pd.read_csv(position0 + "/df_equil_new002_added_res_0_10.csv")

# %%
heatmap0_6 = dset_new2.pivot("c_0_b", "c_0_a", "pr1")
sns.set(rc={'figure.figsize':(18.7,10.27),'figure.dpi': 100})
ax = sns.heatmap(heatmap0_6, cmap="YlGnBu", linewidths=.5, annot=True, 
                 annot_kws={'size':10},fmt='.1f')
ax.invert_yaxis()
plt.show()

# %%
heatmap0_6 = dset_new2.pivot("c_0_b", "c_0_a", "pr2")
sns.set(rc={'figure.figsize':(18.7,10.27),'figure.dpi': 100})
ax = sns.heatmap(heatmap0_6, cmap="YlGnBu", linewidths=.5, annot=True, 
                 annot_kws={'size':10},fmt='.1f')
ax.invert_yaxis()
plt.show()

# %%
heatmap0_6 = dset_new2.pivot("c_0_b", "c_0_a", "price_s_a")
sns.set(rc={'figure.figsize':(18.7,10.27),'figure.dpi': 100})
ax = sns.heatmap(heatmap0_6, cmap="YlGnBu", linewidths=.5, annot=True, 
                 annot_kws={'size':10},fmt='.1f')
ax.invert_yaxis()
plt.show()

# %%
heatmap0_6 = dset_new2.pivot("c_0_b", "c_0_a", "price_s_b")
sns.set(rc={'figure.figsize':(18.7,10.27),'figure.dpi': 100})
ax = sns.heatmap(heatmap0_6, cmap="YlGnBu", linewidths=.5, annot=True, 
                 annot_kws={'size':10},fmt='.1f')
ax.invert_yaxis()
plt.show()

# %%
dset_new3 = pd.read_csv(position0 + "/df_equil_new002_added_res_10_10.csv")
heatmap0_6 = dset_new3.pivot("c_0_b", "c_0_a", "price_s_b")
sns.set(rc={'figure.figsize':(18.7,10.27),'figure.dpi': 100})
ax = sns.heatmap(heatmap0_6, cmap="YlGnBu", linewidths=.5, annot=True, 
                 annot_kws={'size':10},fmt='.1f')
ax.invert_yaxis()
plt.show()

# %%
dset_new3 = pd.read_csv(position0 + "/df_equil_new002_added_res_10_10.csv")
heatmap0_6 = dset_new3.pivot("c_0_b", "c_0_a", "price_s_a")
sns.set(rc={'figure.figsize':(18.7,10.27),'figure.dpi': 100})
ax = sns.heatmap(heatmap0_6, cmap="YlGnBu", linewidths=.5, annot=True, 
                 annot_kws={'size':10},fmt='.1f')
ax.invert_yaxis()
plt.show()

# %%
dset_new1 = pd.read_excel(position0 + "/df_equil_new002_add_res_0_0.xlsx")
heatmap0_6 = dset_new1.pivot("c_0_b", "c_0_a", "price_s_a")
sns.set(rc={'figure.figsize':(18.7,10.27),'figure.dpi': 100})
ax = sns.heatmap(heatmap0_6, cmap="YlGnBu", linewidths=.5, annot=True, annot_kws={'size':10},fmt='.1f')
ax.invert_yaxis()
plt.show()

# %%
dset_new3 = pd.read_csv(position0 + "/df_equil_new002_added_res_10_10.csv")
dset_new3.to_excel(position0 + "/df_equil_new002_add_res_10_10.xlsx", index = False)

# %%
dset_new4 = pd.read_csv(position0 + "/df_equil_new002_added_res_0_10.csv")
dset_new4.to_excel(position0 + "/df_equil_new002_add_res_0_10.xlsx", index = False)

# %% [markdown]
# New Analyses

# %%
dset_an01 = pd.read_excel(position0 + "/df_equil_new002_add_res_0_0.xlsx")
dset_an02 = pd.read_excel(position0 + "/df_equil_new002_add_res_0_10.xlsx")
dset_an03 = pd.read_excel(position0 + "/df_equil_new002_add_res_10_10.xlsx")

# %%
heatmap01_price_a = dset_an01.pivot("c_0_b", "c_0_a", "agg_welfare") # price_s_a, price_s_b, pr1, pr2, agg_welfare
sns.set(rc={'figure.figsize':(18.7,10.27),'figure.dpi': 100})
ax = sns.heatmap(heatmap01_price_a, cmap="YlGnBu", linewidths=.5, annot=True, 
                 annot_kws={'size':10},fmt='.1f')
ax.invert_yaxis()
plt.show()

# %%
heatmap02_price_a = dset_an02.pivot("c_0_b", "c_0_a", "agg_welfare") # price_s_a, price_s_b, pr1, pr2, agg_welfare
sns.set(rc={'figure.figsize':(18.7,10.27),'figure.dpi': 100}) # res0_10_price_a
ax = sns.heatmap(heatmap02_price_a, cmap="YlGnBu", linewidths=.5, annot=True, 
                 annot_kws={'size':10},fmt='.1f')
ax.invert_yaxis()
plt.show()

# %%
heatmap03_price_a = dset_an03.pivot("c_0_b", "c_0_a", "agg_welfare") # price_s_a, price_s_b, pr1, pr2, agg_welfare
sns.set(rc={'figure.figsize':(18.7,10.27),'figure.dpi': 100}) # res10_10_price_a
ax = sns.heatmap(heatmap03_price_a, cmap="YlGnBu", linewidths=.5, annot=True, 
                 annot_kws={'size':10},fmt='.1f')
ax.invert_yaxis()
plt.show()

# %%
heatmap01_price_a = dset_an01.pivot("c_0_a", "c_0_b", "price_s_b")
sns.set(rc={'figure.figsize':(18.7,10.27),'figure.dpi': 100})
ax = sns.heatmap(heatmap0_6, cmap="YlGnBu", linewidths=.5, annot=True, annot_kws={'size':10},fmt='.1f')
ax.invert_yaxis()
plt.show()

# %% [markdown]
# Finer Grids

# %%
dset_an01 = pd.read_excel(position + "/df_equil_new002_0728_res_0_0_r1.xlsx")

# %%
dset_an01
# Out:
#      c_0_a  c_0_b  price_s_a  price_s_b  m1   m2      pr1      pr2  total_pr  \
# 0      0.0    0.0          1          1  45   55   45.000   55.000   100.000
# 1      0.0    0.5          1          1   0  100    0.000   99.875    99.875
# 2      0.0    1.0          1          2   0  100    0.000  199.000   199.000
# 3      0.0    1.5          1          3   1   99    1.000  293.625   294.625
# 4      0.0    2.0          1          4  17   83   17.000  324.000   341.000
# ..     ...    ...        ...        ...  ..  ...      ...      ...       ...
# 226    9.0    9.5          1          1   0  100 -729.000 -757.375 -1486.375
# 227    9.0   10.0          1          2   0  100 -729.000 -800.000 -1529.000
# 228    9.5    9.5          1          1  45   55 -812.375 -802.375 -1614.750
# 229    9.5   10.0          1          1   0  100 -857.375 -900.000 -1757.375
# 230   10.0   10.0          1          1  45   55 -955.000 -945.000 -1900.000
#
#       agg_welfare
# 0     9963.610623
# ...
